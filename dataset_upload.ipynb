# %% [markdown]
# # Dataset Upload

# %% [markdown]
# In addition to creating and editing Datasets in the LangSmith UI, you can also create and edit datasets with the LangSmith SDK.

# %% [markdown]
# Let's go ahead an upload a list of examples that we have from our RAG application to LangSmith as a new dataset.

# %%
# You can set them inline
import os
os.environ["OPENAI_API_KEY"] = ""
os.environ["LANGSMITH_API_KEY"] = ""
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langsmith-academy"

# %%
# Or you can use a .env file
from dotenv import load_dotenv
load_dotenv(dotenv_path="../../.env", override=True)
# Out:
# True

# %%
from langsmith import Client

example_inputs = [
("How do I set up tracing to LangSmith if I'm using LangChain?", "To set up tracing to LangSmith while using LangChain, you need to set the environment variable `LANGSMITH_TRACING` to 'true'. Additionally, you must set the `LANGSMITH_API_KEY` environment variable to your API key. By default, traces will be logged to a project named \"default.\""),
("How can I trace with the @traceable decorator?", "To trace with the @traceable decorator in Python, simply decorate any function you want to log traces for by adding `@traceable` above the function definition. Ensure that the LANGSMITH_TRACING environment variable is set to 'true' to enable tracing, and also set the LANGSMITH_API_KEY environment variable with your API key. By default, traces will be logged to a project named \"default,\" but you can configure it to log to a different project if needed."),
("How do I pass metadata in with @traceable?", "You can pass metadata with the @traceable decorator by specifying arbitrary key-value pairs as arguments. This allows you to associate additional information, such as the execution environment or user details, with your traces. For more detailed instructions, refer to the LangSmith documentation on adding metadata and tags."),
("What is LangSmith used for in three sentences?", "LangSmith is a platform designed for the development, monitoring, and testing of LLM applications. It enables users to collect and analyze unstructured data, debug issues, and create datasets for testing and evaluation. The tool supports various workflows throughout the application development lifecycle, enhancing the overall performance and reliability of LLM applications."),
("What testing capabilities does LangSmith have?", "LangSmith offers capabilities for creating datasets of inputs and reference outputs to run tests on LLM applications, supporting a test-driven approach. It allows for bulk uploads of test cases, on-the-fly creation, and exporting from application traces. Additionally, LangSmith facilitates custom evaluations to score test results, enhancing the testing process."),
("Does LangSmith support online evaluation?", "Yes, LangSmith supports online evaluation as a feature. It allows you to configure a sample of runs from production to be evaluated, providing feedback on those runs. You can use either custom code or an LLM as a judge for the evaluations."),
("Does LangSmith support offline evaluation?", "Yes, LangSmith supports offline evaluation through its evaluation how-to guides and features for managing datasets. Users can manage datasets for offline evaluations and run various types of evaluations, including unit testing and auto-evaluation. This allows for comprehensive testing and improvement of LLM applications."),
("Can LangSmith be used for finetuning and model training?", "Yes, LangSmith can be used for fine-tuning and model training. It allows you to capture run traces from your deployment, query and filter this data, and convert it into a format suitable for fine-tuning models. Additionally, you can create training datasets to keep track of the data used for model training."),
("Can LangSmith be used to evaluate agents?", "Yes, LangSmith can be used to evaluate agents. It provides various evaluation strategies, including assessing the agent's final response, evaluating individual steps, and analyzing the trajectory of tool calls. These methods help ensure the effectiveness of LLM applications."),
("How do I create user feedback with the LangSmith sdk?", "To create user feedback with the LangSmith SDK, you first need to run your application and obtain the `run_id`. Then, you can use the `create_feedback` method, providing the `run_id`, a feedback key, a score, and an optional comment. For example, in Python, it would look like this: `client.create_feedback(run_id, key=\"feedback-key\", score=1.0, comment=\"comment\")`."),
]

client = Client()
# TODO: Fill in dataset id
dataset_id = "e4097e19-17e5-4f1b-addb-ed1669ff45d7"

# Prepare inputs and outputs for bulk creation
inputs = [{"question": input_prompt} for input_prompt, _ in example_inputs]
outputs = [{"output": output_answer} for _, output_answer in example_inputs]

client.create_examples(
  inputs=inputs,
  outputs=outputs,
  dataset_id="e4097e19-17e5-4f1b-addb-ed1669ff45d7",
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langsmith\utils.py:159, in raise_for_status_with_text(response)
#     158 try:
# --> 159     response.raise_for_status()
#     160 except requests.HTTPError as e:
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.smith.langchain.com/v1/platform/datasets/e4097e19-17e5-4f1b-addb-ed1669ff45d7/examples
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langsmith\client.py:937, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     931     response = self.session.request(
#     932         method,
#     933         _construct_url(self.api_url, pathname),
#     934         stream=False,
#     935         **request_kwargs,
#     936     )
# --> 937 ls_utils.raise_for_status_with_text(response)
#     938 return response
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langsmith\utils.py:161, in raise_for_status_with_text(response)
#     160 except requests.HTTPError as e:
# --> 161     raise requests.HTTPError(str(e), response.text) from e  # type: ignore[call-arg]
#     162 except httpx.HTTPStatusError as e:
#
# HTTPError: [Errno 404 Client Error: Not Found for url: https://api.smith.langchain.com/v1/platform/datasets/e4097e19-17e5-4f1b-addb-ed1669ff45d7/examples] {"error":"Dataset not found: dataset not found: no rows in result set"}
#
#
# During handling of the above exception, another exception occurred:
#
# LangSmithNotFoundError                    Traceback (most recent call last)
# Cell In[5], line 24
#      21 inputs = [{"question": input_prompt} for input_prompt, _ in example_inputs]
#      22 outputs = [{"output": output_answer} for _, output_answer in example_inputs]
# ---> 24 client.create_examples(
#      25   inputs=inputs,
#      26   outputs=outputs,
#      27   dataset_id="e4097e19-17e5-4f1b-addb-ed1669ff45d7",
#      28 )
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langsmith\utils.py:147, in xor_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     141     invalid_group_names = [", ".join(arg_groups[i]) for i in invalid_groups]
#     142     raise ValueError(
#     143         "Exactly one argument in each of the following"
#     144         " groups must be defined:"
#     145         f" {', '.join(invalid_group_names)}"
#     146     )
# --> 147 return func(*args, **kwargs)
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langsmith\client.py:4992, in Client.create_examples(self, dataset_name, dataset_id, examples, dangerously_allow_filesystem, **kwargs)
#    4968     uploads = [
#    4969         ls_schemas.ExampleCreate(
#    4970             **{
#    (...)   4986         )
#    4987     ]
#    4989 if (self.info.instance_flags or {}).get(
#    4990     "dataset_examples_multipart_enabled", False
#    4991 ):
# -> 4992     return self._upload_examples_multipart(
#    4993         dataset_id=cast(uuid.UUID, dataset_id),
#    4994         uploads=uploads,
#    4995         dangerously_allow_filesystem=dangerously_allow_filesystem,
#    4996     )
#    4997 else:
#    4998     for upload in uploads:
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langsmith\client.py:4784, in Client._upload_examples_multipart(self, dataset_id, uploads, dangerously_allow_filesystem)
#    4777 encoder, data, opened_files_dict = self._prepare_multipart_data(
#    4778     uploads,
#    4779     include_dataset_id=False,
#    4780     dangerously_allow_filesystem=dangerously_allow_filesystem,
#    4781 )
#    4783 try:
# -> 4784     response = self.request_with_retries(
#    4785         "POST",
#    4786         _dataset_examples_path(self.api_url, dataset_id),
#    4787         request_kwargs={
#    4788             "data": data,
#    4789             "headers": {
#    4790                 **self._headers,
#    4791                 "Content-Type": encoder.content_type,
#    4792             },
#    4793         },
#    4794     )
#    4795     ls_utils.raise_for_status_with_text(response)
#    4796 finally:
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langsmith\client.py:977, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     972     raise ls_utils.LangSmithAuthError(
#     973         f"Authentication failed for {pathname}. {repr(e)}"
#     974         f"{_context}"
#     975     )
#     976 elif response.status_code == 404:
# --> 977     raise ls_utils.LangSmithNotFoundError(
#     978         f"Resource not found for {pathname}. {repr(e)}"
#     979         f"{_context}"
#     980     )
#     981 elif response.status_code == 409:
#     982     raise ls_utils.LangSmithConflictError(
#     983         f"Conflict for {pathname}. {repr(e)}{_context}"
#     984     )
#
# LangSmithNotFoundError: Resource not found for /v1/platform/datasets/e4097e19-17e5-4f1b-addb-ed1669ff45d7/examples. HTTPError('404 Client Error: Not Found for url: https://api.smith.langchain.com/v1/platform/datasets/e4097e19-17e5-4f1b-addb-ed1669ff45d7/examples', '{"error":"Dataset not found: dataset not found: no rows in result set"}\n')

# %% [markdown]
# ## Submitting another Trace

# %% [markdown]
# I've moved our RAG application definition to `app.py` so we can quickly import it.

# %%
from app import langsmith_rag
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# Let's ask another question to create a new trace!

# %%
question = "How do I set up tracing to LangSmith if I'm using LangChain?"
langsmith_rag(question)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 question = "How do I set up tracing to LangSmith if I'm using LangChain?"
# ----> 2 langsmith_rag(question)
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langsmith\run_helpers.py:693, in traceable.<locals>.decorator.<locals>.wrapper(langsmith_extra, *args, **kwargs)
#     689         function_result = run_container["context"].run(
#     690             run_with_otel_context
#     691         )
#     692     else:
# --> 693         function_result = run_container["context"].run(
#     694             func, *args, **kwargs
#     695         )
#     696 except BaseException as e:
#     697     _cleanup_traceback(e)
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\notebooks\module_2\app.py:109, in langsmith_rag(question)
#     107 @traceable(run_type="chain")
#     108 def langsmith_rag(question: str):
# --> 109     documents = retrieve_documents(question)
#     110     response = generate_response(question, documents)
#     111     return response.choices[0].message.content
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langsmith\run_helpers.py:693, in traceable.<locals>.decorator.<locals>.wrapper(langsmith_extra, *args, **kwargs)
#     689         function_result = run_container["context"].run(
#     690             run_with_otel_context
#     691         )
#     692     else:
# --> 693         function_result = run_container["context"].run(
#     694             func, *args, **kwargs
#     695         )
#     696 except BaseException as e:
#     697     _cleanup_traceback(e)
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\notebooks\module_2\app.py:63, in retrieve_documents(question)
#      61 @traceable(run_type="chain")
#      62 def retrieve_documents(question: str):
# ---> 63     return retriever.invoke(question)
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langchain_core\retrievers.py:263, in BaseRetriever.invoke(self, input, config, **kwargs)
#     261 kwargs_ = kwargs if self._expects_other_args else {}
#     262 if self._new_arg_supported:
# --> 263     result = self._get_relevant_documents(
#     264         input, run_manager=run_manager, **kwargs_
#     265     )
#     266 else:
#     267     result = self._get_relevant_documents(input, **kwargs_)
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langchain_core\vectorstores\base.py:1067, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1065 kwargs_ = self.search_kwargs | kwargs
#    1066 if self.search_type == "similarity":
# -> 1067     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1068 elif self.search_type == "similarity_score_threshold":
#    1069     docs_and_similarities = (
#    1070         self.vectorstore.similarity_search_with_relevance_scores(
#    1071             query, **kwargs_
#    1072         )
#    1073     )
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langchain_community\vectorstores\sklearn.py:256, in SKLearnVectorStore.similarity_search(self, query, k, **kwargs)
#     253 def similarity_search(
#     254     self, query: str, k: int = DEFAULT_K, **kwargs: Any
#     255 ) -> List[Document]:
# --> 256     docs_scores = self.similarity_search_with_score(query, k=k, **kwargs)
#     257     return [doc for doc, _ in docs_scores]
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langchain_community\vectorstores\sklearn.py:238, in SKLearnVectorStore.similarity_search_with_score(self, query, k, **kwargs)
#     235 def similarity_search_with_score(
#     236     self, query: str, *, k: int = DEFAULT_K, **kwargs: Any
#     237 ) -> List[Tuple[Document, float]]:
# --> 238     query_embedding = self._embedding_function.embed_query(query)
#     239     indices_dists = self._similarity_index_search_with_score(
#     240         query_embedding, k=k, **kwargs
#     241     )
#     242     return [
#     243         (
#     244             Document(
#    (...)    250         for idx, dist in indices_dists
#     251     ]
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:640, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     630 def embed_query(self, text: str, **kwargs: Any) -> list[float]:
#     631     """Call out to OpenAI's embedding endpoint for embedding query text.
#     632
#     633     Args:
#    (...)    638         Embedding for the text.
#     639     """
# --> 640     return self.embed_documents([text], **kwargs)[0]
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:592, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     589 # NOTE: to keep things simple, we assume the list may contain texts longer
#     590 #       than the maximum context and use length-safe embedding function.
#     591 engine = cast(str, self.deployment)
# --> 592 return self._get_len_safe_embeddings(
#     593     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     594 )
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:482, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     480 batched_embeddings: list[list[float]] = []
#     481 for i in _iter:
# --> 482     response = self.client.create(
#     483         input=tokens[i : i + _chunk_size], **client_kwargs
#     484     )
#     485     if not isinstance(response, dict):
#     486         response = response.model_dump()
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\openai\resources\embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Kashvi Tak\intro-to-langsmith\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************cFEA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
